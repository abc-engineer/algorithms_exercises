# %% [markdown]
# ### Hire-assistant 고용비용 계산
#
#
# 기본 의사코드
#
# ```text
# HIRE-ASSISTANT(n)
#   best = 0          // 0번은 가장 낮은 점수를 갖는 가상의 지원자다.
#   for i = 1 to n
#       지원자 i를 면접한다.
#       if 지원자 i가 지원자 best보다 나은가?
#           best = i
#           지원자 i를 고용한다.
#
# ```
