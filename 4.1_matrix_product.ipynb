# %% [markdown]
# ### matrix_product 벡터곱
#
#
#
# $ A=\begin{pmatrix} \ a_{11}&a_{12}\\ a_{21}&a_{22}\end{pmatrix}, B=\begin{pmatrix} \ b_{11}&b_{12}\\ b_{21}&b_{22}\end{pmatrix}$ 일때,
#
# $ A \times B= C \begin{pmatrix} \ c_{11}&c_{12}\\ c_{21}&c_{22}\end{pmatrix}$ 를 구하기
