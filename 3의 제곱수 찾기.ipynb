# %%
T=list(range(1,10001))
#2의 제곱을 리스트 2**i
# 2의 제곱은 <= T

i=0
a=[]
while (2**i) < max(T):
    a.append(2**i)
    i+=1

n=1
if n in a:
    print(str(n)+" 은(는) 2의 제곱입니다.")
else:
    print(str(n)+" 은(는) 2의 제곱이 아닙니다.")
# Out:
# 1 은(는) 2의 제곱입니다.

# %% [markdown]
# 문제 분석
# 입력 조건:
#
# 첫 줄에 판별해야 하는 데이터의 개수
# 𝑇
# T가 주어집니다.
# 1
# ≤
# 𝑇
# ≤
# 3
# ,
# 000
# ,
# 000
# 1≤T≤3,000,000
# 두 번째 줄에
# 𝑇
# T개의 정수가 공백으로 구분되어 주어지며, 각 정수는
# 0
# ≤
# 𝑇
# 𝑖
# ≤
# 2
# 64
# −
# 1
# 0≤T
# i
# ​
#  ≤2
# 64
#  −1 범위에 있습니다.
# 요구 사항: 각 정수가 2의 제곱수인지 빠르게 판별합니다.
#
# 알고리즘 설계
# 2의 제곱수 판별 방법:
#
# 어떤 정수
# 𝑛
# n이 2의 제곱수라면, 이진수로 표현했을 때 1이 1개만 포함됩니다.
# 예:
# 2
# 3
# =
# 8
# 2
# 3
#  =8 → 1000 (1이 하나)
# 2
# 0
# =
# 1
# 2
# 0
#  =1 → 1
# 이를 활용한 판별 조건:
# 𝑛
# n이 0이 아니고,
# 𝑛
# &
# (
# 𝑛
# −
# 1
# )
# =
# =
# 0
# n&(n−1)==0이면 2의 제곱수입니다.
# 이유:
# 𝑛
# &
# (
# 𝑛
# −
# 1
# )
# =
# =
# 0
# n&(n−1)==0인 경우는
# 𝑛
# n이 이진수에서 유일한 1 비트를 가지고 있을 때만 참이 됩니다.
#
# 입력 데이터의 크기가 최대 3,000,000개이므로, 판별을 매우 빠르게 해야 합니다. 이 알고리즘은 O(1) 시간 복잡도로 동작합니다.
#
# 코드 구현
# python
# 코드 복사
# import sys
#
# # 입력 받기 (빠른 입력 사용)
# input = sys.stdin.read
# data = input().split()
#
# # 첫 번째 줄: 데이터 개수 T
# T = int(data[0])
#
# # 결과를 저장할 리스트
# results = []
#
# # 두 번째 줄 이후: 각 정수에 대해 2의 제곱수 판별
# for i in range(1, T + 1):
#     num = int(data[i])
#     if num != 0 and (num & (num - 1)) == 0:
#         results.append("YES")
#     else:
#         results.append("NO")
#
# # 결과 한 번에 출력
# sys.stdout.write("\n".join(results) + "\n")
# 코드 설명
# sys.stdin.read(): 빠른 입력을 위해 사용합니다. 전체 입력을 한 번에 읽고 공백으로 분리합니다.
# (num & (num - 1)) == 0: 해당 조건을 이용해 각 정수가 2의 제곱수인지 판별합니다.
# 결과 저장: 결과를 리스트에 저장한 뒤, 한 번에 출력합니다. (I/O 시간을 줄이기 위해)
# 입출력 예시
# 입력:
#
# 코드 복사
# 5
# 1 2 3 4 5
# 출력:
#
# objectivec
# 코드 복사
# YES
# YES
# NO
# YES
# NO
# 시간 복잡도
# 입력:
# 𝑂
# (
# 𝑇
# )
# O(T)
# 판별: 각 수에 대해 O(1)
# 출력:
# 𝑂
# (
# 𝑇
# )
# O(T)
# 따라서 전체 시간 복잡도는 **O(T)**로 매우 빠릅니다.
#
# 이제 이 코드를 사용하면 최대 3,000,000개의 정수에 대해 빠르게 2의 제곱수 판별을 할 수 있습니다! 😊

# %%
import sys

# 입력 받기 (빠른 입력 사용)
input = sys.stdin.read
data = input().split()

# 첫 번째 줄: 데이터 개수 T
T = int(data[0])

# 결과를 저장할 리스트
results = []

# 두 번째 줄 이후: 각 정수에 대해 2의 제곱수 판별
for i in range(1, T + 1):
    num = int(data[i])
    if num != 0 and (num & (num - 1)) == 0:
        results.append("YES")
    else:
        results.append("NO")

# 결과 한 번에 출력
sys.stdout.write("\n".join(results) + "\n")

# %%
n=list(range(5))

def square(x):
    square_n=3**x
    return square_n

result=map(square,n)

print(list(result))
# Out:
# [1, 3, 9, 27, 81]

# %%
n=list(range(5))

result=map(lambda x:3**x,n)

print(list(result))
# Out:
# [1, 3, 9, 27, 81]

# %%
n=list(range(5))
a=[]
for i in n:
    a.append(3**i)
print(a)
# Out:
# [1, 3, 9, 27, 81]

# %%
n=list(range(5))
a=[3**i for i in n]
a
# Out:
# [1, 3, 9, 27, 81]

# %%
n=list(range(0,7,3))
n
# Out:
# [0, 3, 6]
